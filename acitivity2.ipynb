# %%
print("Unang Aktibidad")
# Out:
# Unang Aktibidad

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
birds = pd.read_csv('datasets//penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %%
birds.sex
# Out:
# 0        male
# 1      female
# 2      female
# 3         NaN
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %% [markdown]
# what is the average body mass of a penguin

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
birds.describe() .T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %%
birds['weight_kilo'] = np.round(birds['body_mass_g'] / 1000,1)

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight_kilo           2
# dtype: int64

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight_kilo           2
# dtype: int64

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds['weight_kilo'] = birds['weight_kilo'].fillna(birds['weight_kilo'].mean())

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight_kilo          0
# dtype: int64

# %%
birds['year'] = birds['year'].astype('category')

# %%
birds['species'] = birds['species'].astype('category')

# %%
birds['rowid'] = birds['rowid'].astype('category')

# %%
birds['island'] = birds['island'].astype('category')

# %%
birds['sex'] = birds['sex'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight_kilo        344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
birds.head(10)
# Out:
#   rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0     1  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1     2  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2     3  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3     4  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4     5  Adelie  Torgersen        36.70000       19.30000         193.000000
# 5     6  Adelie  Torgersen        39.30000       20.60000         190.000000
# 6     7  Adelie  Torgersen        38.90000       17.80000         181.000000
# 7     8  Adelie  Torgersen        39.20000       19.60000         195.000000
# 8     9  Adelie  Torgersen        34.10000       18.10000         193.000000
# 9    10  Adelie  Torgersen        42.00000       20.20000         190.000000
#
#    body_mass_g     sex  year  weight_kilo
# 0  3750.000000    male  2007     3.800000
# ...

# %%
birds['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight_kilo          68
# dtype: int64

# %%
birds[birds['species'] == "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight_kilo          152
# dtype: int64

# %%
birds[birds['species'] == "Gentoo"].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight_kilo          124
# dtype: int64

# %% [markdown]
# <h1>
#     HOW MANY GENTOO SPECIES HAVE WEIGHT MORE THAN 3kg?
# </h1>

# %%
birds[(birds['weight_kilo'] < 3) & (birds['species'] == "Gentoo")].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight_kilo          0
# dtype: int64

# %% [markdown]
# <h1>
#     HOW MANY GENTOO SPECIES HAVE WEIGHT LESS THAN 3kg?
# </h1>

# %%
birds[(birds['weight_kilo'] > 3) & (birds['species'] == "Gentoo")].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight_kilo          124
# dtype: int64

# %% [markdown]
# <H1>DOES GENTOO EXCLUSIVELY LIVE ON JUST ONE ISLAND?</H1>

# %%
birds['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == 'Gentoo']
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year  weight_kilo
# ...

# %%
birds['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
Gentoo_Biscoe = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')]

# %%
Gentoo_Biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year  weight_kilo
# ...

# %%
Gentoo_Dream = birds[(birds['species'] == 'Dream') & (birds['island'] == 'Biscoe')]

# %%
Gentoo_Dream
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight_kilo]
# Index: []

# %%
Gentoo_Torgersen = birds[(birds['species'] == 'Torgersen') & (birds['island'] == 'Biscoe')]

# %%
Gentoo_Torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight_kilo]
# Index: []

# %% [markdown]
# <h1>INSIGHT N0.1
# <h2>Gentoo lives exclusively on Biscoe</h2>

# %%
Adelie_Biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
Adelie_Biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
Adelie_Dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]

# %%
Adelie_Dream
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %%
Adelie_Torgersen = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]

# %%
Adelie_Torgersen
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        39.10000       18.70000
# 1       2  Adelie  Torgersen        39.50000       17.40000
# 2       3  Adelie  Torgersen        40.30000       18.00000
# 3       4  Adelie  Torgersen        43.92193       17.15117
# 4       5  Adelie  Torgersen        36.70000       19.30000
# 5       6  Adelie  Torgersen        39.30000       20.60000
# 6       7  Adelie  Torgersen        38.90000       17.80000
# 7       8  Adelie  Torgersen        39.20000       19.60000
# 8       9  Adelie  Torgersen        34.10000       18.10000
# 9      10  Adelie  Torgersen        42.00000       20.20000
# 10     11  Adelie  Torgersen        37.80000       17.10000
# 11     12  Adelie  Torgersen        37.80000       17.30000
# 12     13  Adelie  Torgersen        41.10000       17.60000
# 13     14  Adelie  Torgersen        38.60000       21.20000
# 14     15  Adelie  Torgersen        34.60000       21.10000
# ...

# %% [markdown]
# <h1>INSIGHT N0.2
# <h2>Adelie lives on all three islands</h2>

# %%
Chinstrap_Biscoe = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Biscoe')]

# %%
Chinstrap_Biscoe
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight_kilo]
# Index: []

# %%
Chinstrap_Dream = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Dream')]

# %%
Chinstrap_Dream
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276   277  Chinstrap  Dream            46.5           17.9              192.0
# 277   278  Chinstrap  Dream            50.0           19.5              196.0
# 278   279  Chinstrap  Dream            51.3           19.2              193.0
# 279   280  Chinstrap  Dream            45.4           18.7              188.0
# 280   281  Chinstrap  Dream            52.7           19.8              197.0
# ..    ...        ...    ...             ...            ...                ...
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# 340   341  Chinstrap  Dream            43.5           18.1              202.0
# 341   342  Chinstrap  Dream            49.6           18.2              193.0
# 342   343  Chinstrap  Dream            50.8           19.0              210.0
# 343   344  Chinstrap  Dream            50.2           18.7              198.0
#
# ...

# %%
Chinstrap_Torgersen = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Torgersen')]

# %%
Chinstrap_Torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight_kilo]
# Index: []

# %% [markdown]
# <h1>INSIGHT N0.3
# <h2>Chinstrap lives exclusively on Dream</h2>

# %% [markdown]
# <h1>QUESTION NO.4
# <h2>DO ADELIE'S SPECIE AFFECTS THE WEIGHT BASED ON THE ISLAND IT LIVES</h2>

# %%
Adelie_Biscoe_W = np.round(Adelie_Biscoe['weight_kilo'].mean(),2)

# %%
Adelie_Biscoe_W
# Out:
# np.float64(3.72)

# %%
Adelie_Dream_W = np.round(Adelie_Dream['weight_kilo'].mean(),2)

# %%
Adelie_Dream_W
# Out:
# np.float64(3.69)

# %%
Adelie_Torgersen_W = np.round(Adelie_Torgersen['weight_kilo'].mean(),2)

# %%
Adelie_Torgersen_W
# Out:
# np.float64(3.71)

# %% [markdown]
# <h1>INSIGHT N0.4
# <h2>THE WEIGHT OF THE ADELIE SPECIE DOES NOT IMPACT WETHER IT LIVES ON ANY OF THE THREE ISLANDS</h2>

# %%
Gentoo_Biscoe_W = np.round(Gentoo_Biscoe['weight_kilo'].mean(),1)

# %%
Gentoo_Biscoe_W
# Out:
# np.float64(5.1)

# %% [markdown]
# <h1>INSIGHT N0.5
# <h2>THE AVERAGE WEIGHT OF THE GENTOO SPECIE IS HEAVIER IN TERMS OF ITS SPECIE</h2>

# %%
Chinstrap_Dream_W = np.round(Chinstrap_Dream['weight_kilo'].mean(),1)

# %%
Chinstrap_Dream_W
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>INSIGHT N0.6
# <h2>THE AVERAGE WEIGHT OF THE CHINSTRAP SPECIE IN DREAM IS THE SAME FOR ADELIE IN TERMS OF ITS AVERAGE WEIGHT</h2>

# %% [markdown]
# <h1>INSIGHT N0.7
# <h2>THE GENTOO SPECIE IN BISCOE IS THE HEAVIEST AMONG THE THREE SPECIES</h2>

# %% [markdown]
# <h2>HOW TO USE GROUPBY()</h2>
#
# <OL>
#     <LI>NAME THE GROUPBY() REFERENCE DATA FRAME</LI>
#     <LI>CALL THE DATAFRAME</LI>
#     <LI>.GROUPBY FUNCTION</LI>
#     <LI>COLUMNS TO GROUP</LI>
#     <LI>GROUP BY FUNCTION</LI>
# </OL>

# %%
birds_agg1 = birds.groupby(['species', 'island']).size()
# Out:
# C:\Users\LAB4-StudentPC03\AppData\Local\Temp\ipykernel_15032\1511608000.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg1 = birds.groupby(['species', 'island']).size()

# %%
birds_agg1
# Out:
# species    island
# Adelie     Biscoe        44
#            Dream         56
#            Torgersen     52
# Chinstrap  Biscoe         0
#            Dream         68
#            Torgersen      0
# Gentoo     Biscoe       124
#            Dream          0
#            Torgersen      0
# dtype: int64

# %% [markdown]
# <h1>
#     INSIGHT NO.1-3
# </h1>
# <h1>Island residence per specie</h1>
# <ol>
#     <li>There are scattered Adelie specie on each island</li>
#     <li>There are 68 Chinstrap penguins exclusively on Dream</li>
#     <li>There are 124 Gentoo penguins exclusively on Biscoe</li>
# </ol>

# %%
birds_agg2 = np.round(birds.groupby(['species', 'island'])['weight_kilo'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC03\AppData\Local\Temp\ipykernel_15032\3335494670.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg2 = np.round(birds.groupby(['species', 'island'])['weight_kilo'].mean(),1)

# %%
birds_agg2
# Out:
# species    island
# Adelie     Biscoe       3.7
#            Dream        3.7
#            Torgersen    3.7
# Chinstrap  Biscoe       NaN
#            Dream        3.7
#            Torgersen    NaN
# Gentoo     Biscoe       5.1
#            Dream        NaN
#            Torgersen    NaN
# Name: weight_kilo, dtype: float64

# %% [markdown]
# <h1>
#     INSIGHT NO.4-6
# </h1>
# <h1>Average weight of each penguin specie in each islands</h1>
# <ol>
#     <li>The Average weight of Adelie specie on all islands is 3.7 Kilos</li>
#     <li>The Average weight of Chinstrap specie on Dream is also 3.7 Kilos</li>
#     <li>The Average weight of Gentoo specie on Biscoe is 5.1 Kilos</li>
# </ol>

# %% [markdown]
# <h1>
#     INSIGHT NO.7
# </h1>
# <h1>The heaviest specie is Gentoo that lives exclusively on Biscoe </h1>

# %%
birds_agg3 = birds.groupby(['species', 'island','year','sex']).size()
# Out:
# C:\Users\LAB4-StudentPC03\AppData\Local\Temp\ipykernel_15032\2639247255.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg3 = birds.groupby(['species', 'island','year','sex']).size()

# %%
birds_agg3.unstack()
# Out:
# sex                       female  male
# species   island    year
# Adelie    Biscoe    2007       5     5
#                     2008       9     9
#                     2009       8     8
#           Dream     2007       9    11
#                     2008       8     8
#                     2009      10    10
#           Torgersen 2007       8    12
#                     2008       8     8
#                     2009       8     8
# Chinstrap Biscoe    2007       0     0
#                     2008       0     0
#                     2009       0     0
#           Dream     2007      13    13
#                     2008       9     9
#                     2009      12    12
#           Torgersen 2007       0     0
#                     2008       0     0
#                     2009       0     0
# Gentoo    Biscoe    2007      16    18
#                     2008      22    24
#                     2009      20    24
#           Dream     2007       0     0
# ...

# %% [markdown]
# <h1>
#     INSIGHT NO.8
# </h1>
# <h1>The oldest penguin in adelie is a male in Torgersen in 2007 </h1>

# %%
birds_agg4 = np.round(birds.groupby(['species', 'island','sex'])['weight_kilo'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC03\AppData\Local\Temp\ipykernel_15032\3798003495.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg4 = np.round(birds.groupby(['species', 'island','sex'])['weight_kilo'].mean(),1)

# %%
birds_agg4
# Out:
# species    island     sex
# Adelie     Biscoe     female    3.4
#                       male      4.1
#            Dream      female    3.3
#                       male      4.0
#            Torgersen  female    3.4
#                       male      4.0
# Chinstrap  Biscoe     female    NaN
#                       male      NaN
#            Dream      female    3.5
#                       male      3.9
#            Torgersen  female    NaN
#                       male      NaN
# Gentoo     Biscoe     female    4.7
#                       male      5.4
#            Dream      female    NaN
#                       male      NaN
#            Torgersen  female    NaN
#                       male      NaN
# Name: weight_kilo, dtype: float64

# %% [markdown]
# <h1>
#     INSIGHT NO.9-11
# </h1>
# <h1>Average weight per sex of each penguin specie in each islands</h1>
# <ol>
#     <li>The Average weight of Adelie specie on all islands for female is 3.4 Kilos and male is 4.1 Kilos</li>
#     <li>The Average weight of Chinstrap specie on Dream for female is 3.5 Kilos and male is 3.9 Kilos</li>
#     <li>The Average weight of Gentoo specie on Biscoe for female is 4.7 Kilos and male is 5.4 Kilos</li>
# </ol>

# %% [markdown]
# <h1>Does the bill length of a penguin affects the bill depth as it goes long or short?</h1>

# %%
b_length_depth = birds['bill_length_mm'].corr(birds['bill_depth_mm'])

# %%
b_length_depth
# Out:
# np.float64(-0.23505287035553282)

# %% [markdown]
# <h1>
#     INSIGHT NO.12
# </h1>
#
# <p>The bill length does not affect the bill depth of a penguin as it goes long or short</p>

# %% [markdown]
# <h1>Does the weight of the penguin affects its flipper length?</h1>

# %%
b_flipper_mass = birds['flipper_length_mm'].corr(birds['weight_kilo'])

# %%
b_flipper_mass
# Out:
# np.float64(0.8706550442461823)

# %% [markdown]
# <h1>INSIGHT NO.13</h1>
#
# <p>The weight does affect the flipper length of the penguin as it goes longer</p>

# %% [markdown]
# <h1>Does the bill length affect the flipper length?</h1>

# %%
b_flipper_mass = birds['flipper_length_mm'].corr(birds['weight_kilo'])

# %%
b_flipper_mass
# Out:
# np.float64(0.8706550442461823)

# %% [markdown]
# <h1>INSIGHT NO.14</h1>
#
# <p>The bill length does affect the flipper length of the penguin is it both gets longer</p>

# %% [markdown]
# <h1>Does the bill depth affect the weight of the penguin?</h1>

# %%
b_depth_mass = birds['bill_depth_mm'].corr(birds['weight_kilo'])

# %%
b_depth_mass
# Out:
# np.float64(-0.4707176291681673)

# %% [markdown]
# <h1>INSIGHT NO.15</h1>
#
# <p>The bill depth does affect the weight of the penguin</p>

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight_kilo        344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h2>requirements for one way anova</h2>
# <h3>Filter columns and  its data</h3>

# %%
birds[birds['sex'] == 'male']['weight_kilo']
# Out:
# 0      3.800000
# 3      4.202047
# 5      3.600000
# 7      4.700000
# 8      3.500000
#          ...
# 334    3.800000
# 336    4.000000
# 339    4.000000
# 341    3.800000
# 342    4.100000
# Name: weight_kilo, Length: 179, dtype: float64

# %%
birds[birds['sex'] == 'female']['weight_kilo']
# Out:
# 1      3.8
# 2      3.2
# 4      3.4
# 6      3.6
# 12     3.2
#       ...
# 335    3.5
# 337    3.6
# 338    3.6
# 340    3.4
# 343    3.8
# Name: weight_kilo, Length: 165, dtype: float64

# %%
f_stats, p_value = f_oneway(birds[birds['sex']=='male']['weight_kilo'],
                          birds[birds['sex']=='female']['weight_kilo'])

print(p_value)
# Out:
# 2.5288724247849435e-15

# %% [markdown]
# <h1>INSIGHT NO.16</h1>
#
# <h2>There is a correlation between sex and body mass</h2>
