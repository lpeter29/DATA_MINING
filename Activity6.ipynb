# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
import folium
from folium.plugins import HeatMap
warnings.filterwarnings('ignore')

# %%
# Load the dataset with the correct encoding
df = pd.read_csv('datasets\\Global_terrorist.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df['region_txt'].unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
filters = df[(df['region_txt'] == 'East Asia') & (df['attacktype1_txt'] == 'Bombing/Explosion')]
filters
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1085    197111200002   1971      11    20        NaN         0        NaN
# 2842    197502280001   1975       2    28        NaN         0        NaN
# 2959    197504190001   1975       4    19        NaN         0        NaN
# 3043    197505250001   1975       5    25        NaN         0        NaN
# 3044    197505250002   1975       5    25        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 169510  201611200065   2016      11    20        NaN         0        NaN
# 170675  201612280005   2016      12    28        NaN         0        NaN
# 171274  201701180014   2017       1    18        NaN         0        NaN
# 171275  201701180015   2017       1    18        NaN         0        NaN
# 175948  201706150025   2017       6    15        NaN         0        NaN
#
#         country country_txt  region  ...  \
# 1085        201      Taiwan       4  ...
# 2842        101       Japan       4  ...
# 2959        101       Japan       4  ...
# 3043        101       Japan       4  ...
# 3044        101       Japan       4  ...
# ...         ...         ...     ...  ...
# 169510       44       China       4  ...
# 170675       44       China       4  ...
# 171274       44       China       4  ...
# 171275       44       China       4  ...
# 175948       44       China       4  ...
#
#                                                  addnotes  \
# 1085                                                  NaN
# 2842                                                  NaN
# 2959                                                  NaN
# 3043                                                  NaN
# 3044                                                  NaN
# ...                                                   ...
# 169510  Casualty numbers represent a division of the t...
# 170675  Casualty numbers conflict across sources. Foll...
# 171274                                                NaN
# 171275                                                NaN
# 175948  Sources stated that Xu had previously been dia...
#
#                                                    scite1  \
# 1085                                                  NaN
# 2842                                                  NaN
# 2959                                                  NaN
# 3043                                                  NaN
# 3044                                                  NaN
# ...                                                   ...
# 169510  "Burma: Kachin rebels waging 'limited war' in ...
# 170675  "Attack on Communist party office in Xinjiang;...
# 171274  "Mastermind arrested after Chinas double bus ...
# 171275  "Mastermind arrested after Chinas double bus ...
# 175948  "SCMP: Nine Victims Of China School Blast Stil...
#
#                                                    scite2  \
# 1085                                                  NaN
# 2842                                                  NaN
# 2959                                                  NaN
# 3043                                                  NaN
# 3044                                                  NaN
# ...                                                   ...
# 169510                                                NaN
# 170675  "4 Militants Who Attacked Communist Party Of C...
# 171274  "Six injured in two Chinese bus blasts," South...
# 171275  "Six injured in two Chinese bus blasts," South...
# 175948  "Explosion at Chinese kindergarten kills eight...
#
#                                                    scite3  \
# 1085                                                  NaN
# 2842                                                  NaN
# 2959                                                  NaN
# 3043                                                  NaN
# 3044                                                  NaN
# ...                                                   ...
# 169510                                                NaN
# 170675  "China police kill four over Xinjiang attack: ...
# 171274                                                NaN
# 171275                                                NaN
# 175948  "SCMP: Eight Killed And 65 Injured In Kinderga...
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 1085                        PGIS       -9        -9        1       1
# 2842                        PGIS        0         0        0       0
# 2959                        PGIS        0         1        1       1
# 3043                        PGIS        0         0        0       0
# 3044                        PGIS        0         0        0       0
# ...                          ...      ...       ...      ...     ...
# 169510  START Primary Collection        1         1        0       1
# 170675  START Primary Collection        0         0        0       0
# 171274  START Primary Collection       -9        -9        0      -9
# 171275  START Primary Collection       -9        -9        0      -9
# 175948  START Primary Collection       -9        -9        0      -9
#
#                            related
# 1085                           NaN
# 2842                           NaN
# 2959                           NaN
# 3043                           NaN
# 3044                           NaN
# ...                            ...
# 169510  201611200064, 201611200065
# 170675                         NaN
# 171274  201701180014, 201701180015
# 171275  201701180014, 201701180015
# 175948                         NaN
#
# [330 rows x 135 columns]
